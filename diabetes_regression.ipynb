# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkan-motamedifar/diabetes-linear-regression/blob/main/diabetes_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_diabetes
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import numpy as np

# %%
diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
intercept = model.intercept_
coefficients = model.coef_
print("Intercept:", intercept)
print("Coefficients:", coefficients)
# Out:
# Intercept: 151.00821291456543
# Coefficients: [  29.25401303 -261.7064691   546.29972304  388.39834056 -901.95966819
#   506.76324136  121.15435079  288.03526689  659.26895081   41.37670105]

# %%
y_pred = model.predict(X_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 41.91937845679274
# Mean Squared Error: 2821.750981001311
# R-squared: 0.4772897164322617

# %%
plt.scatter(y_test, y_pred, color="blue", alpha=0.6)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         "r--", lw=2)  # perfect prediction line
plt.xlabel("Actual progression")
plt.ylabel("Predicted progression")
plt.title("Linear Regression: Actual vs Predicted")
plt.show()

# %%
features = diabetes.feature_names

plt.bar(features, coefficients)
plt.xticks(rotation=45)
plt.ylabel("Coefficient value")
plt.title("Feature importance (Linear Regression)")
plt.show()
